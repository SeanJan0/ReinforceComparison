# %% [markdown]
# # Importing dependancies

# %%
import gym

import numpy as np
import random
from collections import namedtuple, deque

import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Model definition
#
# We can use the state variables (position of cart, angle of pole)

# %%
class DQN(nn.Module):

    def __init__(self, output_size):
        super(DQN, self).__init__()
        self.fn1 = nn.LazyLinear(64)
        self.fn2 = nn.LazyLinear(64)
        self.fn3 = nn.LazyLinear(output_size)
        self.act = nn.PReLU()

    def forward(self, input):
        x = self.act(self.fn1(input))
        x = self.act(self.fn2(x))
        output = self.fn3(x)
        return output

# %% [markdown]
# # Memory
# The agent should memorize what it learned before so it can learn from it

# %%
Experience = namedtuple('Experience', ('curr_state', 'action', 'next_state', 'reward', 'is_going'))

class Memory(object):

    def __init__(self, capacity):
        self.memory = deque([],maxlen=capacity)

    def remember(self, *args):
        self.memory.append(Experience(*args))

    def recall(self, batch_size):
        experiences = random.sample(self.memory, batch_size)
        batch = Experience(*zip(*experiences))
        return batch

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# # Creating the agent

# %%
class DDQNAgent:
    def __init__(self, env):
        env.reset()
        self.action_size = env.action_space.n # output size
        
        self.policy_model = DQN(self.action_size).to(device)
        self.target_model = DQN(self.action_size).to(device)
        self.target_model.load_state_dict(self.policy_model.state_dict())

        self.loss_fn = nn.SmoothL1Loss()
        self.optimizer = optim.Adam(self.policy_model.parameters(), lr=0.0005)

        self.exploration_rate = 1 # initial exploration rate, always leave at 1
        self.exploration_rate_decay = 0.99995 # rate at which the exploration decreases
        self.exploration_rate_min = 0.1 # minimun exploration rate
        
        self.gamma = 0.995 # falloff for Q score

        self.batch_size = 64
        self.num_epochs = 250
        self.img_size = 100
        self.update_rate = 5

        self.memory = Memory(10000) # how many of the previous samples are used
    
    def act(self, state):
        if random.random() < self.exploration_rate:
            action = random.randrange(self.action_size) # act randomly
        else:
            action = self.act_ideal(state) # act ideally
            
        self.exploration_rate *= self.exploration_rate_decay
        self.exploration_rate = max(self.exploration_rate_min, self.exploration_rate)
        
        return action
    
    def act_ideal(self, state):
        return self.policy_model(state).max(1)[1].item()
    
    def train_step(self):
        if len(self.memory) < self.batch_size:
            return
        batch = self.memory.recall(self.batch_size)
        
        curr_states = torch.stack(batch.curr_state).squeeze(1)
        actions = torch.Tensor(np.array(batch.action)).to(device)
        next_states = torch.stack(batch.next_state).squeeze(1)
        rewards = torch.Tensor(np.array(batch.reward)).to(device)
        is_goings = torch.Tensor(np.array(batch.is_going)).to(device)
        
        # This is the fundamental logic behind calulating a deep Q value.
        curr_Q = self.policy_model(curr_states).mul(actions).sum(1)
        next_Q = self.target_model(next_states).max(1)[0]
        expected_Q = rewards + is_goings * self.gamma * next_Q

        loss = self.loss_fn(expected_Q, curr_Q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    def train(self, env, print_epochs=False, render=False):

        scores = []

        for epoch in range(self.num_epochs):
            done = False
            curr_state = env.reset()
            curr_state = torch.Tensor(curr_state).to(device)
            score = 0
            
            while not done:
                if render:
                    env.render()

                action = self.act(curr_state.unsqueeze(0))
                next_state, reward, done, _ = env.step(action)
                next_state = torch.Tensor(next_state).to(device)
                action_encode = np.eye(self.action_size)[action]
                self.memory.remember(curr_state, action_encode, next_state, reward, 1 - done)

                curr_state = next_state
                      
                self.train_step()

                score += 1
            
            scores.append(score)

            if epoch % self.update_rate == 0:
                self.target_model.load_state_dict(self.policy_model.state_dict())

            if print_epochs:
                print("Epoch: " + str(epoch + 1) + ". Score is: " + str(score))
            
            
        return scores

    def test(self, env, num_trials=100, render=False):
        test_scores = []

        for i in range(num_trials):

            done = False
            curr_state = env.reset()
            curr_state = torch.Tensor(curr_state).to(device)
            score = 0

            while not done:

                if render:
                    env.render()

                action = self.act_ideal(curr_state.unsqueeze(0))
                curr_state, _, done, _ = env.step(action)
                curr_state = torch.Tensor(curr_state).to(device)

                score += 1
            
            test_scores.append(score)
            
        return sum(test_scores) / num_trials

# %% [markdown]
# # Training the agent

# %%
env = gym.make("CartPole-v0")
agent = DDQNAgent(env)
env.reset()
scores = agent.train(env, print_epochs=True, render=False)
plt.plot(scores)
plt.show()
print(agent.test(env))
# Out:
# Epoch: 1. Score is: 12
# Epoch: 2. Score is: 23
# Epoch: 3. Score is: 93
# Epoch: 4. Score is: 14
# Epoch: 5. Score is: 31
# Epoch: 6. Score is: 8
# Epoch: 7. Score is: 25
# Epoch: 8. Score is: 13
# Epoch: 9. Score is: 46
# Epoch: 10. Score is: 9
# Epoch: 11. Score is: 28
# Epoch: 12. Score is: 19
# Epoch: 13. Score is: 11
# Epoch: 14. Score is: 10
# Epoch: 15. Score is: 16
# Epoch: 16. Score is: 12
# Epoch: 17. Score is: 13
# Epoch: 18. Score is: 25
# Epoch: 19. Score is: 18
# Epoch: 20. Score is: 11
# Epoch: 21. Score is: 23
# Epoch: 22. Score is: 33
# Epoch: 23. Score is: 62
# Epoch: 24. Score is: 22
# Epoch: 25. Score is: 11
# Epoch: 26. Score is: 27
# Epoch: 27. Score is: 15
# Epoch: 28. Score is: 39
# Epoch: 29. Score is: 13
# Epoch: 30. Score is: 9
# Epoch: 31. Score is: 32
# Epoch: 32. Score is: 14
# Epoch: 33. Score is: 18
# Epoch: 34. Score is: 21
# Epoch: 35. Score is: 43
# Epoch: 36. Score is: 60
# Epoch: 37. Score is: 33
# Epoch: 38. Score is: 42
# Epoch: 39. Score is: 27
# Epoch: 40. Score is: 37
# Epoch: 41. Score is: 20
# Epoch: 42. Score is: 14
# Epoch: 43. Score is: 18
# Epoch: 44. Score is: 38
# Epoch: 45. Score is: 29
# Epoch: 46. Score is: 20
# Epoch: 47. Score is: 22
# Epoch: 48. Score is: 9
# Epoch: 49. Score is: 16
# Epoch: 50. Score is: 13
# Epoch: 51. Score is: 10
# Epoch: 52. Score is: 33
# Epoch: 53. Score is: 18
# Epoch: 54. Score is: 22
# Epoch: 55. Score is: 27
# Epoch: 56. Score is: 16
# Epoch: 57. Score is: 18
# Epoch: 58. Score is: 16
# Epoch: 59. Score is: 39
# Epoch: 60. Score is: 12
# Epoch: 61. Score is: 36
# Epoch: 62. Score is: 16
# Epoch: 63. Score is: 10
# Epoch: 64. Score is: 56
# Epoch: 65. Score is: 16
# Epoch: 66. Score is: 14
# Epoch: 67. Score is: 16
# Epoch: 68. Score is: 28
# Epoch: 69. Score is: 16
# Epoch: 70. Score is: 30
# Epoch: 71. Score is: 70
# Epoch: 72. Score is: 21
# Epoch: 73. Score is: 39
# Epoch: 74. Score is: 15
# Epoch: 75. Score is: 47
# Epoch: 76. Score is: 19
# Epoch: 77. Score is: 32
# Epoch: 78. Score is: 13
# Epoch: 79. Score is: 21
# Epoch: 80. Score is: 60
# Epoch: 81. Score is: 18
# Epoch: 82. Score is: 24
# Epoch: 83. Score is: 17
# Epoch: 84. Score is: 15
# Epoch: 85. Score is: 23
# Epoch: 86. Score is: 19
# Epoch: 87. Score is: 54
# Epoch: 88. Score is: 21
# Epoch: 89. Score is: 17
# Epoch: 90. Score is: 54
# Epoch: 91. Score is: 15
# Epoch: 92. Score is: 15
# Epoch: 93. Score is: 23
# Epoch: 94. Score is: 21
# Epoch: 95. Score is: 11
# Epoch: 96. Score is: 23
# Epoch: 97. Score is: 18
# Epoch: 98. Score is: 41
# Epoch: 99. Score is: 28
# Epoch: 100. Score is: 15
# Epoch: 101. Score is: 26
# Epoch: 102. Score is: 22
# Epoch: 103. Score is: 25
# Epoch: 104. Score is: 44
# Epoch: 105. Score is: 25
# Epoch: 106. Score is: 77
# Epoch: 107. Score is: 35
# Epoch: 108. Score is: 41
# Epoch: 109. Score is: 13
# Epoch: 110. Score is: 32
# Epoch: 111. Score is: 14
# Epoch: 112. Score is: 30
# Epoch: 113. Score is: 62
# Epoch: 114. Score is: 89
# Epoch: 115. Score is: 37
# Epoch: 116. Score is: 14
# Epoch: 117. Score is: 20
# Epoch: 118. Score is: 40
# Epoch: 119. Score is: 23
# Epoch: 120. Score is: 14
# Epoch: 121. Score is: 33
# Epoch: 122. Score is: 21
# Epoch: 123. Score is: 13
# Epoch: 124. Score is: 103
# Epoch: 125. Score is: 13
# Epoch: 126. Score is: 38
# Epoch: 127. Score is: 46
# Epoch: 128. Score is: 79
# Epoch: 129. Score is: 29
# Epoch: 130. Score is: 26
# Epoch: 131. Score is: 14
# Epoch: 132. Score is: 36
# Epoch: 133. Score is: 13
# Epoch: 134. Score is: 39
# Epoch: 135. Score is: 13
# Epoch: 136. Score is: 26
# Epoch: 137. Score is: 48
# Epoch: 138. Score is: 22
# Epoch: 139. Score is: 49
# Epoch: 140. Score is: 26
# Epoch: 141. Score is: 27
# Epoch: 142. Score is: 91
# Epoch: 143. Score is: 28
# Epoch: 144. Score is: 21
# Epoch: 145. Score is: 13
# Epoch: 146. Score is: 10
# Epoch: 147. Score is: 36
# Epoch: 148. Score is: 41
# Epoch: 149. Score is: 17
# Epoch: 150. Score is: 29
# Epoch: 151. Score is: 96
# Epoch: 152. Score is: 36
# Epoch: 153. Score is: 10
# Epoch: 154. Score is: 21
# Epoch: 155. Score is: 17
# Epoch: 156. Score is: 120
# Epoch: 157. Score is: 22
# Epoch: 158. Score is: 47
# Epoch: 159. Score is: 52
# Epoch: 160. Score is: 22
# Epoch: 161. Score is: 17
# Epoch: 162. Score is: 16
# Epoch: 163. Score is: 12
# Epoch: 164. Score is: 41
# Epoch: 165. Score is: 72
# Epoch: 166. Score is: 33
# Epoch: 167. Score is: 14
# Epoch: 168. Score is: 69
# Epoch: 169. Score is: 33
# Epoch: 170. Score is: 11
# Epoch: 171. Score is: 14
# Epoch: 172. Score is: 64
# Epoch: 173. Score is: 21
# Epoch: 174. Score is: 45
# Epoch: 175. Score is: 38
# Epoch: 176. Score is: 16
# Epoch: 177. Score is: 28
# Epoch: 178. Score is: 19
# Epoch: 179. Score is: 20
# Epoch: 180. Score is: 23
# Epoch: 181. Score is: 61
# Epoch: 182. Score is: 18
# Epoch: 183. Score is: 27
# Epoch: 184. Score is: 15
# Epoch: 185. Score is: 15
# Epoch: 186. Score is: 86
# Epoch: 187. Score is: 104
# Epoch: 188. Score is: 44
# Epoch: 189. Score is: 26
# Epoch: 190. Score is: 16
# Epoch: 191. Score is: 23
# Epoch: 192. Score is: 19
# Epoch: 193. Score is: 56
# Epoch: 194. Score is: 49
# Epoch: 195. Score is: 32
# Epoch: 196. Score is: 36
# Epoch: 197. Score is: 83
# Epoch: 198. Score is: 24
# Epoch: 199. Score is: 27
# Epoch: 200. Score is: 54
# Epoch: 201. Score is: 92
# Epoch: 202. Score is: 77
# Epoch: 203. Score is: 25
# Epoch: 204. Score is: 11
# Epoch: 205. Score is: 44
# Epoch: 206. Score is: 21
# Epoch: 207. Score is: 41
# Epoch: 208. Score is: 37
# Epoch: 209. Score is: 30
# Epoch: 210. Score is: 74
# Epoch: 211. Score is: 36
# Epoch: 212. Score is: 43
# Epoch: 213. Score is: 62
# Epoch: 214. Score is: 88
# Epoch: 215. Score is: 93
# Epoch: 216. Score is: 19
# Epoch: 217. Score is: 12
# Epoch: 218. Score is: 58
# Epoch: 219. Score is: 75
# Epoch: 220. Score is: 15
# Epoch: 221. Score is: 42
# Epoch: 222. Score is: 19
# Epoch: 223. Score is: 29
# Epoch: 224. Score is: 29
# Epoch: 225. Score is: 24
# Epoch: 226. Score is: 179
# Epoch: 227. Score is: 122
# Epoch: 228. Score is: 102
# Epoch: 229. Score is: 17
# Epoch: 230. Score is: 53
# Epoch: 231. Score is: 38
# Epoch: 232. Score is: 26
# Epoch: 233. Score is: 45
# Epoch: 234. Score is: 19
# Epoch: 235. Score is: 59
# Epoch: 236. Score is: 57
# Epoch: 237. Score is: 42
# Epoch: 238. Score is: 39
# Epoch: 239. Score is: 25
# Epoch: 240. Score is: 67
# Epoch: 241. Score is: 31
# Epoch: 242. Score is: 101
# Epoch: 243. Score is: 65
# Epoch: 244. Score is: 61
# Epoch: 245. Score is: 113
# Epoch: 246. Score is: 13
# Epoch: 247. Score is: 33
# Epoch: 248. Score is: 20
# Epoch: 249. Score is: 95
# Epoch: 250. Score is: 72
# 192.99
