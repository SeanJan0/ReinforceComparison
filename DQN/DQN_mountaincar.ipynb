# %% [markdown]
# # Importing dependancies

# %%
import gym

import numpy as np
import random
from collections import namedtuple, deque

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Model definition
#
# We can use the state variables (position of cart, angle of pole)

# %%
class DQN(nn.Module):

    def __init__(self, output_size):
        super(DQN, self).__init__()
        self.fn1 = nn.LazyLinear(64)
        self.fn2 = nn.LazyLinear(64)
        self.fn3 = nn.LazyLinear(output_size)
        self.act = nn.PReLU()

    def forward(self, input):
        x = self.act(self.fn1(input))
        x = self.act(self.fn2(x))
        output = self.fn3(x)
        return output

# %% [markdown]
# # Memory
# The agent should memorize what it learned before so it can learn from it

# %%
Experience = namedtuple('Experience', ('curr_state', 'action', 'next_state', 'reward', 'is_going'))

class Memory(object):

    def __init__(self, capacity):
        self.memory = deque([],maxlen=capacity)

    def remember(self, *args):
        self.memory.append(Experience(*args))

    def recall(self, batch_size):
        experiences = random.sample(self.memory, batch_size)
        batch = Experience(*zip(*experiences))
        return batch

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# # Creating the agent

# %%
class DDQNAgent:
    def __init__(self, env):
        env.reset()
        self.action_size = env.action_space.n # output size
        
        self.policy_model = DQN(self.action_size).to(device)
        self.target_model = DQN(self.action_size).to(device)
        self.target_model.load_state_dict(self.policy_model.state_dict())

        self.loss_fn = nn.SmoothL1Loss()
        self.optimizer = optim.Adam(self.policy_model.parameters(), lr=0.0005)

        self.exploration_rate = 1 # initial exploration rate, always leave at 1
        self.exploration_rate_decay = 0.9999 # rate at which the exploration decreases
        self.exploration_rate_min = 0.1 # minimun exploration rate
        
        self.gamma = 0.995 # falloff for Q score

        self.batch_size = 64
        self.num_epochs = 500
        self.img_size = 100
        self.update_rate = 5

        self.memory = Memory(10000) # how many of the previous samples are used
    
    def act(self, state):
        if random.random() < self.exploration_rate:
            action = random.randrange(self.action_size) # act randomly
        else:
            action = self.act_ideal(state) # act ideally
            
        self.exploration_rate *= self.exploration_rate_decay
        self.exploration_rate = max(self.exploration_rate_min, self.exploration_rate)
        
        return action
    
    def act_ideal(self, state):
        return self.policy_model(state).max(1)[1].item()
    
    def train_step(self):
        if len(self.memory) < self.batch_size:
            return
        batch = self.memory.recall(self.batch_size)
        
        curr_states = torch.stack(batch.curr_state).squeeze(1)
        actions = torch.Tensor(np.array(batch.action)).to(device)
        next_states = torch.stack(batch.next_state).squeeze(1)
        rewards = torch.Tensor(np.array(batch.reward)).to(device)
        is_goings = torch.Tensor(np.array(batch.is_going)).to(device)
        
        # This is the fundamental logic behind calulating a deep Q value.
        curr_Q = self.policy_model(curr_states).mul(actions).sum(1)
        next_Q = self.target_model(next_states).max(1)[0]
        expected_Q = rewards + is_goings * self.gamma * next_Q

        loss = self.loss_fn(expected_Q, curr_Q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    def train(self, env, print_epochs=False, render=False):

        scores = []

        for epoch in range(self.num_epochs):
            done = False
            curr_state = env.reset()
            curr_state = torch.Tensor(curr_state).to(device)
            score = 0
            
            while not done:
                if render:
                    env.render()

                action = self.act(curr_state.unsqueeze(0))
                next_state, reward, done, _ = env.step(action)
                next_state = torch.Tensor(next_state).to(device)
                action_encode = np.eye(self.action_size)[action]
                self.memory.remember(curr_state, action_encode, next_state, reward, 1 - done)

                curr_state = next_state

                score += reward
                      
                self.train_step()

            if epoch % self.update_rate == 0:
                self.target_model.load_state_dict(self.policy_model.state_dict())

            scores.append(score)
            if print_epochs:
                print("Epoch: " + str(epoch + 1) + ". Score is: " + str(score))

            
        return scores

    def test(self, env, num_trials=100, render=False):
        test_scores = []

        for i in range(num_trials):

            done = False
            curr_state = env.reset()
            curr_state = torch.Tensor(curr_state).to(device)
            score = 0

            while not done:
                if score < curr_state[0].item():
                    score = curr_state[0].item()

                if render:
                    env.render()

                action = self.act_ideal(curr_state.unsqueeze(0))
                curr_state, _, done, _ = env.step(action)
                curr_state = torch.Tensor(curr_state).to(device)
            
            test_scores.append(score)
            
        return sum(test_scores) / num_trials

# %% [markdown]
# # Training the agent

# %%
env = gym.make("MountainCar-v0")
agent = DDQNAgent(env)
env.reset()
scores = agent.train(env, print_epochs=True, render=False)
plt.plot(scores)
plt.show()
# Out:
# Epoch: 1. Score is: -200.0
# Epoch: 2. Score is: -200.0
# Epoch: 3. Score is: -200.0
# Epoch: 4. Score is: -200.0
# Epoch: 5. Score is: -200.0
# Epoch: 6. Score is: -200.0
# Epoch: 7. Score is: -200.0
# Epoch: 8. Score is: -200.0
# Epoch: 9. Score is: -200.0
# Epoch: 10. Score is: -200.0
# Epoch: 11. Score is: -200.0
# Epoch: 12. Score is: -200.0
# Epoch: 13. Score is: -200.0
# Epoch: 14. Score is: -200.0
# Epoch: 15. Score is: -200.0
# Epoch: 16. Score is: -200.0
# Epoch: 17. Score is: -200.0
# Epoch: 18. Score is: -200.0
# Epoch: 19. Score is: -200.0
# Epoch: 20. Score is: -200.0
# Epoch: 21. Score is: -200.0
# Epoch: 22. Score is: -200.0
# Epoch: 23. Score is: -200.0
# Epoch: 24. Score is: -200.0
# Epoch: 25. Score is: -200.0
# Epoch: 26. Score is: -200.0
# Epoch: 27. Score is: -200.0
# Epoch: 28. Score is: -200.0
# Epoch: 29. Score is: -200.0
# Epoch: 30. Score is: -200.0
# Epoch: 31. Score is: -200.0
# Epoch: 32. Score is: -200.0
# Epoch: 33. Score is: -200.0
# Epoch: 34. Score is: -200.0
# Epoch: 35. Score is: -200.0
# Epoch: 36. Score is: -200.0
# Epoch: 37. Score is: -200.0
# Epoch: 38. Score is: -200.0
# Epoch: 39. Score is: -200.0
# Epoch: 40. Score is: -200.0
# Epoch: 41. Score is: -200.0
# Epoch: 42. Score is: -200.0
# Epoch: 43. Score is: -200.0
# Epoch: 44. Score is: -200.0
# Epoch: 45. Score is: -200.0
# Epoch: 46. Score is: -200.0
# Epoch: 47. Score is: -200.0
# Epoch: 48. Score is: -200.0
# Epoch: 49. Score is: -200.0
# Epoch: 50. Score is: -200.0
# Epoch: 51. Score is: -200.0
# Epoch: 52. Score is: -200.0
# Epoch: 53. Score is: -200.0
# Epoch: 54. Score is: -200.0
# Epoch: 55. Score is: -200.0
# Epoch: 56. Score is: -200.0
# Epoch: 57. Score is: -200.0
# Epoch: 58. Score is: -200.0
# Epoch: 59. Score is: -200.0
# Epoch: 60. Score is: -200.0
# Epoch: 61. Score is: -200.0
# Epoch: 62. Score is: -200.0
# Epoch: 63. Score is: -200.0
# Epoch: 64. Score is: -200.0
# Epoch: 65. Score is: -200.0
# Epoch: 66. Score is: -200.0
# Epoch: 67. Score is: -200.0
# Epoch: 68. Score is: -200.0
# Epoch: 69. Score is: -200.0
# Epoch: 70. Score is: -200.0
# Epoch: 71. Score is: -200.0
# Epoch: 72. Score is: -200.0
# Epoch: 73. Score is: -200.0
# Epoch: 74. Score is: -200.0
# Epoch: 75. Score is: -200.0
# Epoch: 76. Score is: -200.0
# Epoch: 77. Score is: -200.0
# Epoch: 78. Score is: -200.0
# Epoch: 79. Score is: -200.0
# Epoch: 80. Score is: -200.0
# Epoch: 81. Score is: -200.0
# Epoch: 82. Score is: -200.0
# Epoch: 83. Score is: -200.0
# Epoch: 84. Score is: -200.0
# Epoch: 85. Score is: -200.0
# Epoch: 86. Score is: -200.0
# Epoch: 87. Score is: -200.0
# Epoch: 88. Score is: -200.0
# Epoch: 89. Score is: -200.0
# Epoch: 90. Score is: -200.0
# Epoch: 91. Score is: -200.0
# Epoch: 92. Score is: -200.0
# Epoch: 93. Score is: -200.0
# Epoch: 94. Score is: -200.0
# Epoch: 95. Score is: -200.0
# Epoch: 96. Score is: -200.0
# Epoch: 97. Score is: -200.0
# Epoch: 98. Score is: -200.0
# Epoch: 99. Score is: -200.0
# Epoch: 100. Score is: -200.0
# Epoch: 101. Score is: -200.0
# Epoch: 102. Score is: -200.0
# Epoch: 103. Score is: -200.0
# Epoch: 104. Score is: -200.0
# Epoch: 105. Score is: -200.0
# Epoch: 106. Score is: -200.0
# Epoch: 107. Score is: -200.0
# Epoch: 108. Score is: -200.0
# Epoch: 109. Score is: -200.0
# Epoch: 110. Score is: -200.0
# Epoch: 111. Score is: -200.0
# Epoch: 112. Score is: -200.0
# Epoch: 113. Score is: -200.0
# Epoch: 114. Score is: -200.0
# Epoch: 115. Score is: -200.0
# Epoch: 116. Score is: -200.0
# Epoch: 117. Score is: -200.0
# Epoch: 118. Score is: -200.0
# Epoch: 119. Score is: -200.0
# Epoch: 120. Score is: -200.0
# Epoch: 121. Score is: -200.0
# Epoch: 122. Score is: -200.0
# Epoch: 123. Score is: -200.0
# Epoch: 124. Score is: -200.0
# Epoch: 125. Score is: -200.0
# Epoch: 126. Score is: -200.0
# Epoch: 127. Score is: -200.0
# Epoch: 128. Score is: -200.0
# Epoch: 129. Score is: -200.0
# Epoch: 130. Score is: -200.0
# Epoch: 131. Score is: -200.0
# Epoch: 132. Score is: -200.0
# Epoch: 133. Score is: -200.0
# Epoch: 134. Score is: -200.0
# Epoch: 135. Score is: -200.0
# Epoch: 136. Score is: -200.0
# Epoch: 137. Score is: -200.0
# Epoch: 138. Score is: -200.0
# Epoch: 139. Score is: -200.0
# Epoch: 140. Score is: -200.0
# Epoch: 141. Score is: -200.0
# Epoch: 142. Score is: -200.0
# Epoch: 143. Score is: -200.0
# Epoch: 144. Score is: -200.0
# Epoch: 145. Score is: -200.0
# Epoch: 146. Score is: -200.0
# Epoch: 147. Score is: -200.0
# Epoch: 148. Score is: -200.0
# Epoch: 149. Score is: -200.0
# Epoch: 150. Score is: -200.0
# Epoch: 151. Score is: -200.0
# Epoch: 152. Score is: -200.0
# Epoch: 153. Score is: -200.0
# Epoch: 154. Score is: -200.0
# Epoch: 155. Score is: -200.0
# Epoch: 156. Score is: -200.0
# Epoch: 157. Score is: -200.0
# Epoch: 158. Score is: -200.0
# Epoch: 159. Score is: -200.0
# Epoch: 160. Score is: -200.0
# Epoch: 161. Score is: -200.0
# Epoch: 162. Score is: -200.0
# Epoch: 163. Score is: -200.0
# Epoch: 164. Score is: -200.0
# Epoch: 165. Score is: -200.0
# Epoch: 166. Score is: -200.0
# Epoch: 167. Score is: -200.0
# Epoch: 168. Score is: -200.0
# Epoch: 169. Score is: -200.0
# Epoch: 170. Score is: -200.0
# Epoch: 171. Score is: -200.0
# Epoch: 172. Score is: -200.0
# Epoch: 173. Score is: -200.0
# Epoch: 174. Score is: -200.0
# Epoch: 175. Score is: -200.0
# Epoch: 176. Score is: -200.0
# Epoch: 177. Score is: -200.0
# Epoch: 178. Score is: -200.0
# Epoch: 179. Score is: -200.0
# Epoch: 180. Score is: -200.0
# Epoch: 181. Score is: -200.0
# Epoch: 182. Score is: -200.0
# Epoch: 183. Score is: -200.0
# Epoch: 184. Score is: -200.0
# Epoch: 185. Score is: -200.0
# Epoch: 186. Score is: -200.0
# Epoch: 187. Score is: -200.0
# Epoch: 188. Score is: -200.0
# Epoch: 189. Score is: -200.0
# Epoch: 190. Score is: -200.0
# Epoch: 191. Score is: -200.0
# Epoch: 192. Score is: -200.0
# Epoch: 193. Score is: -200.0
# Epoch: 194. Score is: -200.0
# Epoch: 195. Score is: -200.0
# Epoch: 196. Score is: -200.0
# Epoch: 197. Score is: -200.0
# Epoch: 198. Score is: -200.0
# Epoch: 199. Score is: -200.0
# Epoch: 200. Score is: -200.0
# Epoch: 201. Score is: -200.0
# Epoch: 202. Score is: -200.0
# Epoch: 203. Score is: -200.0
# Epoch: 204. Score is: -200.0
# Epoch: 205. Score is: -200.0
# Epoch: 206. Score is: -200.0
# Epoch: 207. Score is: -200.0
# Epoch: 208. Score is: -200.0
# Epoch: 209. Score is: -200.0
# Epoch: 210. Score is: -200.0
# Epoch: 211. Score is: -200.0
# Epoch: 212. Score is: -200.0
# Epoch: 213. Score is: -200.0
# Epoch: 214. Score is: -200.0
# Epoch: 215. Score is: -200.0
# Epoch: 216. Score is: -200.0
# Epoch: 217. Score is: -200.0
# Epoch: 218. Score is: -200.0
# Epoch: 219. Score is: -200.0
# Epoch: 220. Score is: -200.0
# Epoch: 221. Score is: -200.0
# Epoch: 222. Score is: -200.0
# Epoch: 223. Score is: -200.0
# Epoch: 224. Score is: -200.0
# Epoch: 225. Score is: -200.0
# Epoch: 226. Score is: -200.0
# Epoch: 227. Score is: -200.0
# Epoch: 228. Score is: -200.0
# Epoch: 229. Score is: -200.0
# Epoch: 230. Score is: -200.0
# Epoch: 231. Score is: -200.0
# Epoch: 232. Score is: -200.0
# Epoch: 233. Score is: -200.0
# Epoch: 234. Score is: -200.0
# Epoch: 235. Score is: -200.0
# Epoch: 236. Score is: -200.0
# Epoch: 237. Score is: -200.0
# Epoch: 238. Score is: -200.0
# Epoch: 239. Score is: -200.0
# Epoch: 240. Score is: -200.0
# Epoch: 241. Score is: -200.0
# Epoch: 242. Score is: -200.0
# Epoch: 243. Score is: -200.0
# Epoch: 244. Score is: -200.0
# Epoch: 245. Score is: -200.0
# Epoch: 246. Score is: -200.0
# Epoch: 247. Score is: -200.0
# Epoch: 248. Score is: -200.0
# Epoch: 249. Score is: -200.0
# Epoch: 250. Score is: -200.0
# Epoch: 251. Score is: -200.0
# Epoch: 252. Score is: -200.0
# Epoch: 253. Score is: -200.0
# Epoch: 254. Score is: -200.0
# Epoch: 255. Score is: -200.0
# Epoch: 256. Score is: -200.0
# Epoch: 257. Score is: -200.0
# Epoch: 258. Score is: -200.0
# Epoch: 259. Score is: -200.0
# Epoch: 260. Score is: -200.0
# Epoch: 261. Score is: -200.0
# Epoch: 262. Score is: -200.0
# Epoch: 263. Score is: -200.0
# Epoch: 264. Score is: -200.0
# Epoch: 265. Score is: -200.0
# Epoch: 266. Score is: -200.0
# Epoch: 267. Score is: -200.0
# Epoch: 268. Score is: -200.0
# Epoch: 269. Score is: -200.0
# Epoch: 270. Score is: -200.0
# Epoch: 271. Score is: -200.0
# Epoch: 272. Score is: -200.0
# Epoch: 273. Score is: -200.0
# Epoch: 274. Score is: -200.0
# Epoch: 275. Score is: -200.0
# Epoch: 276. Score is: -200.0
# Epoch: 277. Score is: -200.0
# Epoch: 278. Score is: -200.0
# Epoch: 279. Score is: -200.0
# Epoch: 280. Score is: -200.0
# Epoch: 281. Score is: -200.0
# Epoch: 282. Score is: -200.0
# Epoch: 283. Score is: -200.0
# Epoch: 284. Score is: -200.0
# Epoch: 285. Score is: -200.0
# Epoch: 286. Score is: -200.0
# Epoch: 287. Score is: -200.0
# Epoch: 288. Score is: -200.0
# Epoch: 289. Score is: -200.0
# Epoch: 290. Score is: -200.0
# Epoch: 291. Score is: -200.0
# Epoch: 292. Score is: -200.0
# Epoch: 293. Score is: -200.0
# Epoch: 294. Score is: -200.0
# Epoch: 295. Score is: -200.0
# Epoch: 296. Score is: -178.0
# Epoch: 297. Score is: -200.0
# Epoch: 298. Score is: -179.0
# Epoch: 299. Score is: -200.0
# Epoch: 300. Score is: -176.0
# Epoch: 301. Score is: -200.0
# Epoch: 302. Score is: -200.0
# Epoch: 303. Score is: -200.0
# Epoch: 304. Score is: -178.0
# Epoch: 305. Score is: -200.0
# Epoch: 306. Score is: -200.0
# Epoch: 307. Score is: -200.0
# Epoch: 308. Score is: -200.0
# Epoch: 309. Score is: -200.0
# Epoch: 310. Score is: -200.0
# Epoch: 311. Score is: -200.0
# Epoch: 312. Score is: -200.0
# Epoch: 313. Score is: -200.0
# Epoch: 314. Score is: -185.0
# Epoch: 315. Score is: -200.0
# Epoch: 316. Score is: -185.0
# Epoch: 317. Score is: -200.0
# Epoch: 318. Score is: -175.0
# Epoch: 319. Score is: -180.0
# Epoch: 320. Score is: -200.0
# Epoch: 321. Score is: -200.0
# Epoch: 322. Score is: -200.0
# Epoch: 323. Score is: -182.0
# Epoch: 324. Score is: -200.0
# Epoch: 325. Score is: -200.0
# Epoch: 326. Score is: -174.0
# Epoch: 327. Score is: -200.0
# Epoch: 328. Score is: -175.0
# Epoch: 329. Score is: -170.0
# Epoch: 330. Score is: -200.0
# Epoch: 331. Score is: -155.0
# Epoch: 332. Score is: -200.0
# Epoch: 333. Score is: -170.0
# Epoch: 334. Score is: -172.0
# Epoch: 335. Score is: -200.0
# Epoch: 336. Score is: -200.0
# Epoch: 337. Score is: -200.0
# Epoch: 338. Score is: -173.0
# Epoch: 339. Score is: -171.0
# Epoch: 340. Score is: -165.0
# Epoch: 341. Score is: -200.0
# Epoch: 342. Score is: -200.0
# Epoch: 343. Score is: -173.0
# Epoch: 344. Score is: -171.0
# Epoch: 345. Score is: -169.0
# Epoch: 346. Score is: -174.0
# Epoch: 347. Score is: -159.0
# Epoch: 348. Score is: -145.0
# Epoch: 349. Score is: -163.0
# Epoch: 350. Score is: -170.0
# Epoch: 351. Score is: -189.0
# Epoch: 352. Score is: -200.0
# Epoch: 353. Score is: -168.0
# Epoch: 354. Score is: -200.0
# Epoch: 355. Score is: -200.0
# Epoch: 356. Score is: -200.0
# Epoch: 357. Score is: -200.0
# Epoch: 358. Score is: -177.0
# Epoch: 359. Score is: -160.0
# Epoch: 360. Score is: -169.0
# Epoch: 361. Score is: -166.0
# Epoch: 362. Score is: -200.0
# Epoch: 363. Score is: -160.0
# Epoch: 364. Score is: -169.0
# Epoch: 365. Score is: -155.0
# Epoch: 366. Score is: -200.0
# Epoch: 367. Score is: -200.0
# Epoch: 368. Score is: -151.0
# Epoch: 369. Score is: -200.0
# Epoch: 370. Score is: -167.0
# Epoch: 371. Score is: -159.0
# Epoch: 372. Score is: -200.0
# Epoch: 373. Score is: -176.0
# Epoch: 374. Score is: -195.0
# Epoch: 375. Score is: -154.0
# Epoch: 376. Score is: -200.0
# Epoch: 377. Score is: -158.0
# Epoch: 378. Score is: -164.0
# Epoch: 379. Score is: -180.0
# Epoch: 380. Score is: -153.0
# Epoch: 381. Score is: -150.0
# Epoch: 382. Score is: -153.0
# Epoch: 383. Score is: -149.0
# Epoch: 384. Score is: -155.0
# Epoch: 385. Score is: -151.0
# Epoch: 386. Score is: -200.0
# Epoch: 387. Score is: -152.0
# Epoch: 388. Score is: -200.0
# Epoch: 389. Score is: -155.0
# Epoch: 390. Score is: -157.0
# Epoch: 391. Score is: -151.0
# Epoch: 392. Score is: -193.0
# Epoch: 393. Score is: -200.0
# Epoch: 394. Score is: -180.0
# Epoch: 395. Score is: -156.0
# Epoch: 396. Score is: -149.0
# Epoch: 397. Score is: -187.0
# Epoch: 398. Score is: -167.0
# Epoch: 399. Score is: -160.0
# Epoch: 400. Score is: -147.0
# Epoch: 401. Score is: -173.0
# Epoch: 402. Score is: -162.0
# Epoch: 403. Score is: -155.0
# Epoch: 404. Score is: -148.0
# Epoch: 405. Score is: -151.0
# Epoch: 406. Score is: -156.0
# Epoch: 407. Score is: -165.0
# Epoch: 408. Score is: -131.0
# Epoch: 409. Score is: -185.0
# Epoch: 410. Score is: -165.0
# Epoch: 411. Score is: -151.0
# Epoch: 412. Score is: -200.0
# Epoch: 413. Score is: -152.0
# Epoch: 414. Score is: -148.0
# Epoch: 415. Score is: -154.0
# Epoch: 416. Score is: -147.0
# Epoch: 417. Score is: -187.0
# Epoch: 418. Score is: -149.0
# Epoch: 419. Score is: -152.0
# Epoch: 420. Score is: -149.0
# Epoch: 421. Score is: -200.0
# Epoch: 422. Score is: -177.0
# Epoch: 423. Score is: -170.0
# Epoch: 424. Score is: -150.0
# Epoch: 425. Score is: -145.0
# Epoch: 426. Score is: -200.0
# Epoch: 427. Score is: -191.0
# Epoch: 428. Score is: -200.0
# Epoch: 429. Score is: -147.0
# Epoch: 430. Score is: -144.0
# Epoch: 431. Score is: -166.0
# Epoch: 432. Score is: -200.0
# Epoch: 433. Score is: -172.0
# Epoch: 434. Score is: -142.0
# Epoch: 435. Score is: -178.0
# Epoch: 436. Score is: -168.0
# Epoch: 437. Score is: -200.0
# Epoch: 438. Score is: -138.0
# Epoch: 439. Score is: -200.0
# Epoch: 440. Score is: -146.0
# Epoch: 441. Score is: -186.0
# Epoch: 442. Score is: -176.0
# Epoch: 443. Score is: -141.0
# Epoch: 444. Score is: -177.0
# Epoch: 445. Score is: -168.0
# Epoch: 446. Score is: -173.0
# Epoch: 447. Score is: -189.0
# Epoch: 448. Score is: -156.0
# Epoch: 449. Score is: -200.0
# Epoch: 450. Score is: -200.0
# Epoch: 451. Score is: -144.0
# Epoch: 452. Score is: -200.0
# Epoch: 453. Score is: -140.0
# Epoch: 454. Score is: -183.0
# Epoch: 455. Score is: -200.0
# Epoch: 456. Score is: -200.0
# Epoch: 457. Score is: -122.0
# Epoch: 458. Score is: -146.0
# Epoch: 459. Score is: -150.0
# Epoch: 460. Score is: -145.0
# Epoch: 461. Score is: -143.0
# Epoch: 462. Score is: -200.0
# Epoch: 463. Score is: -200.0
# Epoch: 464. Score is: -179.0
# Epoch: 465. Score is: -189.0
# Epoch: 466. Score is: -200.0
# Epoch: 467. Score is: -123.0
# Epoch: 468. Score is: -171.0
# Epoch: 469. Score is: -171.0
# Epoch: 470. Score is: -171.0
# Epoch: 471. Score is: -145.0
# Epoch: 472. Score is: -198.0
# Epoch: 473. Score is: -144.0
# Epoch: 474. Score is: -174.0
# Epoch: 475. Score is: -144.0
# Epoch: 476. Score is: -138.0
# Epoch: 477. Score is: -200.0
# Epoch: 478. Score is: -139.0
# Epoch: 479. Score is: -174.0
# Epoch: 480. Score is: -141.0
# Epoch: 481. Score is: -146.0
# Epoch: 482. Score is: -174.0
# Epoch: 483. Score is: -200.0
# Epoch: 484. Score is: -141.0
# Epoch: 485. Score is: -170.0
# Epoch: 486. Score is: -190.0
# Epoch: 487. Score is: -172.0
# Epoch: 488. Score is: -200.0
# Epoch: 489. Score is: -200.0
# Epoch: 490. Score is: -169.0
# Epoch: 491. Score is: -165.0
# Epoch: 492. Score is: -121.0
# Epoch: 493. Score is: -137.0
# Epoch: 494. Score is: -143.0
# Epoch: 495. Score is: -199.0
# Epoch: 496. Score is: -142.0
# Epoch: 497. Score is: -173.0
# Epoch: 498. Score is: -173.0
# Epoch: 499. Score is: -200.0
# Epoch: 500. Score is: -173.0

# %%
np.save('mountaincar_dqn_scores', scores)
